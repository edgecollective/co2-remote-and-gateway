# %%
import pandas as pd

# %%
#data = pd.read_csv('feather_esp32.csv')
#data2=pd.read_csv('heltec.csv')
heltec_data = pd.read_csv('http://159.65.226.222:3000/api/drives/5bd89f163a158797ab86668e67ac92736905c4056ec03600b8c37b0296da6763/csv?limit=400')
feather32_data=pd.read_csv('http://159.65.226.222:3000/api/drives/516d21cb12f7e724be7c3d1ea66b7113316fb9f4018d2a9345bacf4b05f00c74/csv?limit=400')

# %%
print(heltec_data)
# Out:
#       timestamp  deviceId  bmp_temp  bmp_press   temp  humid  co2  forced
# 0    1607657306        15     20.72    1022.49  22.88  41.26  365       0
# 1    1607657282        15     20.72    1022.49  22.88  41.11  367       1
# 2    1607657251        15     20.73    1022.48  22.91  41.04  367       1
# 3    1607657221        15     20.74    1022.46  22.91  40.99  367       1
# 4    1607657190        15     20.75    1022.49  22.95  41.00  369       1
# ..          ...       ...       ...        ...    ...    ...  ...     ...
# 395  1607649458        15     21.81    1021.91  23.91  41.46  409       1
# 396  1607649447        15     21.81    1021.92  23.91  41.53  409       1
# 397  1607649437        15     21.80    1021.90  23.89  41.53  409       1
# 398  1607649426        15     21.80    1021.92  23.94  41.49  409       1
# 399  1607649415        15     21.80    1021.91  23.89  41.53  409       1
#
# [400 rows x 8 columns]

# %%
x1=heltec_data['timestamp'];y1=heltec_data['co2']
x2=feather32_data['timestamp'];y2=feather32_data['co2']
y1_force=heltec_data['forced']*200
y2_force=feather32_data['forced']*100+50

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12, 8))
plt.plot(x1,y1,label='heltec_revC_scd30')
plt.plot(x1,y1_force,label='heltec_forced')
plt.plot(x2,y2_force,label='feather32_forced')
plt.plot(x2,y2,label='feather32_revB_scd30')
plt.legend()
