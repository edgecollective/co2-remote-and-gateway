# %%
import pandas as pd

# %%
#data = pd.read_csv('feather_esp32.csv')
#data2=pd.read_csv('heltec.csv')
heltec_data = pd.read_csv('http://159.65.226.222:3000/api/drives/5bd89f163a158797ab86668e67ac92736905c4056ec03600b8c37b0296da6763/csv?limit=1000')
feather32_data=pd.read_csv('http://159.65.226.222:3000/api/drives/516d21cb12f7e724be7c3d1ea66b7113316fb9f4018d2a9345bacf4b05f00c74/csv?limit=1000')
#print(heltec_data)
x1=heltec_data['timestamp'];y1=heltec_data['co2']
x2=feather32_data['timestamp'];y2=feather32_data['co2']
y1_force=heltec_data['forced']*200
y2_force=feather32_data['forced']*100+50

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 10))
plt.plot(x1,y1,label='heltec_revC_scd30')
plt.plot(x1,y1_force,label='heltec_forced')
plt.plot(x2,y2_force,label='feather32_forced')
plt.plot(x2,y2,label='feather32_revB_scd30')
plt.legend()

# %%
plt.figure(figsize=(12, 8))
plt.plot(x1,y2-y1,label='feather32 - heltec scd30')
plt.grid(True)
#plt.ylim(-50,50)
plt.legend()

# %% [markdown]
# # closeup

# %%
plt.figure(figsize=(12, 8))
plt.plot(x1,y1,label='heltec_revC_scd30')
plt.plot(x1,y1_force,label='heltec_forced')
plt.plot(x2,y2_force,label='feather32_forced')
plt.plot(x2,y2,label='feather32_revB_scd30')
plt.legend()
plt.xlim(1607656425,1607658496)
# Out:
# (1607656425.0, 1607658496.0)
